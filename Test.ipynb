# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 7)

# %%
result = range(5)
ind = result
number = len(ind)
width = 2 / len(ind)
result_bar = plt.bar(range(number), result, width, color='g')

plt.xticks(np.array(range(number)) + width/2, ind)
# Out:
# ([<matplotlib.axis.XTick at 0xc9a0e10>,
#   <matplotlib.axis.XTick at 0xcea3f28>,
#   <matplotlib.axis.XTick at 0xce90cc0>,
#   <matplotlib.axis.XTick at 0xcee0b00>,
#   <matplotlib.axis.XTick at 0xcee3588>],
#  <a list of 5 Text xticklabel objects>)
